# %% [markdown]
# <a href="https://colab.research.google.com/github/Ilapuramkruthikasaisree/projects/blob/main/Trainingproject2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset Information
# Additional Information
# The dataset consists of feature vectors belonging to 12,330 sessions. The dataset was formed so that each session would belong to a different user in a 1-year period to avoid any tendency to a specific campaign, special day, user profile, or period.
# Additional Variable Information
# The dataset consists of 10 numerical and 8 categorical attributes.
# "Administrative", "Administrative Duration", "Informational", "Informational Duration", "Product Related" and "Product Related Duration" represent the number of different types of pages visited by the visitor in that session and total time spent in each of these page categories.
# The values of these features are derived from the URL information of the pages visited by the user and updated in real time when a user takes an action, e.g. moving from one page to another.
# The "Bounce Rate", "Exit Rate" and "Page Value" features represent the metrics measured by "Google Analytics" for each page in the e-commerce site.
# The value of "Bounce Rate" feature for a web page refers to the percentage of visitors who enter the site from that page and then leave ("bounce") without triggering any other requests to the analytics server during that session.
#  The value of "Exit Rate" feature for a specific web page is calculated as for all pageviews to the page, the percentage that were the last in the session.
# The "Page Value" feature represents the average value for a web page that a user visited before completing an e-commerce transaction.
# The "Special Day" feature indicates the closeness of the site visiting time to a specific special day (e.g. Mother’s Day, Valentine's Day) in which the sessions are more likely to be finalized with transaction.
# The value of this attribute is determined by considering the dynamics of e-commerce such as the duration between the order date and delivery date.
# For example, for Valentina’s day, this value takes a nonzero value between February 2 and February 12, zero before and after this date unless it is close to another special day, and its maximum value of 1 on February 8.
# The dataset also includes operating system, browser, region, traffic type, visitor type as returning or new visitor, a Boolean value indicating whether the date of the visit is weekend, and month of the year.
# Apply the cluster analysis on the above dataset to understand which customers are gives revenue and non-revenue
# Dataset Overview:
# Total Rows: 12,330
# Total Columns: 17
# Data Types:
# Integer (7 columns)
# Float (7 columns)
# Object (2 columns)
# Boolean (1 column)
# Variable Descriptions:
# Administrative (int64) - Number of pages visited related to administrative tasks.
# Administrative_Duration (float64) - Total time spent on administrative pages.
# Informational (int64) - Number of pages visited related to informational content.
# Informational_Duration (float64) - Total time spent on informational pages.
# ProductRelated (int64) - Number of pages visited related to products.
# ProductRelated_Duration (float64) - Total time spent on product-related pages.
# BounceRates (float64) - The percentage of visitors who enter the site and leave without further interaction.
# ExitRates (float64) - The percentage of visitors who leave the site after viewing a specific page.
# PageValues (float64) - A calculated metric representing the economic value of a page before a transaction.
# SpecialDay (float64) - Indicates proximity to a special shopping day (e.g., Black Friday), ranging from 0 to 1.
# Month (object) - The month in which the visit occurred (e.g., 'Feb', 'Mar').
# OperatingSystems (int64) - Encoded categorical variable representing different operating systems.
# Browser (int64) - Encoded categorical variable representing different web browsers.
# Region (int64) - Encoded categorical variable representing different regions.
# TrafficType (int64) - Encoded categorical variable representing different types of web traffic sources.
# VisitorType (object) - Categorical variable indicating whether the visitor is a "Returning_Visitor" or "New_Visitor."
# Weekend (bool) - Boolean variable (True/False) indicating whether the visit occurred on a weekend.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('online_shoppers_intention.csv')

# %%
df
# Out:
#        Administrative  Administrative_Duration  Informational  \
# 0                  26              1861.127910              2
# 1                  25              1022.876853             19
# 2                  20               623.214396              9
# 3                  15               705.246011             21
# 4                  15              1104.862443             14
# ...               ...                      ...            ...
# 97995               1              2093.900453             20
# 97996              27              3392.587490             22
# 97997               6               236.829385             20
# 97998              12              2212.771577             16
# 97999               5              3336.834751             22
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# 0                  886.547213             612             34351.072907
# 1                  426.138361             662             54291.755536
# 2                   86.962291             258             63433.056126
# 3                 2464.867087             485             54948.705992
# 4                 1489.766736             140             16114.466439
# ...                       ...             ...                      ...
# 97995              438.993425             676             63653.493703
# 97996              910.620855              75             17831.242600
# 97997             2213.647664             118             34341.761329
# 97998             2252.237564             483             21171.811242
# 97999              887.764936             379             32484.619848
#
#        BounceRates  ExitRates  PageValues  SpecialDay Month  OperatingSystems  \
# 0         0.052226   0.145315  265.704265    0.613161   Nov                 6
# 1         0.147394   0.159848   53.901211    0.018597   Sep                 2
# 2         0.005921   0.125199  193.612041    0.402715   Nov                 4
# 3         0.121532   0.062180  308.096624    0.949702   Apr                 3
# 4         0.107196   0.003351   41.259382    0.888632   Jun                 3
# ...            ...        ...         ...         ...   ...               ...
# 97995     0.049749   0.068814   26.230931    0.683104   Jul                 2
# 97996     0.105052   0.029734   83.063416    0.619082   Jun                 2
# 97997     0.063482   0.015144  193.672320    0.496868   Dec                 5
# 97998     0.094878   0.085289  352.811203    0.729631   May                 6
# 97999     0.106573   0.044984  261.886125    0.874494   Mar                 2
#
#        Browser  Region  TrafficType        VisitorType  Weekend
# 0            9       8            2        New_Visitor    False
# 1           11       5           19  Returning_Visitor     True
# 2           13       1            3  Returning_Visitor    False
# 3            8       6           19  Returning_Visitor    False
# 4            8       2            5        New_Visitor     True
# ...        ...     ...          ...                ...      ...
# 97995        1       3           14  Returning_Visitor     True
# 97996       11       7            9  Returning_Visitor    False
# 97997        8       5            6              Other    False
# 97998        4       3            9              Other     True
# 97999        9       3           10              Other    False
#
# [98000 rows x 17 columns]

# %%
df.head()
# Out:
#    Administrative  Administrative_Duration  Informational  \
# 0              26              1861.127910              2
# 1              25              1022.876853             19
# 2              20               623.214396              9
# 3              15               705.246011             21
# 4              15              1104.862443             14
#
#    Informational_Duration  ProductRelated  ProductRelated_Duration  \
# 0              886.547213             612             34351.072907
# 1              426.138361             662             54291.755536
# 2               86.962291             258             63433.056126
# 3             2464.867087             485             54948.705992
# 4             1489.766736             140             16114.466439
#
#    BounceRates  ExitRates  PageValues  SpecialDay Month  OperatingSystems  \
# 0     0.052226   0.145315  265.704265    0.613161   Nov                 6
# 1     0.147394   0.159848   53.901211    0.018597   Sep                 2
# 2     0.005921   0.125199  193.612041    0.402715   Nov                 4
# 3     0.121532   0.062180  308.096624    0.949702   Apr                 3
# 4     0.107196   0.003351   41.259382    0.888632   Jun                 3
#
#    Browser  Region  TrafficType        VisitorType  Weekend
# 0        9       8            2        New_Visitor    False
# 1       11       5           19  Returning_Visitor     True
# 2       13       1            3  Returning_Visitor    False
# 3        8       6           19  Returning_Visitor    False
# 4        8       2            5        New_Visitor     True

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
le=LabelEncoder()
df['Month']=le.fit_transform(df['Month'])
df['VisitorType']=le.fit_transform(df['VisitorType'])
df['Weekend']=le.fit_transform(df['Weekend'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98000 entries, 0 to 97999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           98000 non-null  int64
#  1   Administrative_Duration  98000 non-null  float64
#  2   Informational            98000 non-null  int64
#  3   Informational_Duration   98000 non-null  float64
#  4   ProductRelated           98000 non-null  int64
#  5   ProductRelated_Duration  98000 non-null  float64
#  6   BounceRates              98000 non-null  float64
#  7   ExitRates                98000 non-null  float64
#  8   PageValues               98000 non-null  float64
#  9   SpecialDay               98000 non-null  float64
#  10  Month                    98000 non-null  int64
#  11  OperatingSystems         98000 non-null  int64
#  12  Browser                  98000 non-null  int64
#  13  Region                   98000 non-null  int64
#  14  TrafficType              98000 non-null  int64
#  15  VisitorType              98000 non-null  int64
#  16  Weekend                  98000 non-null  int64
# dtypes: float64(7), int64(10)
# memory usage: 12.7 MB

# %%
df.fillna(0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98000 entries, 0 to 97999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           98000 non-null  int64
#  1   Administrative_Duration  98000 non-null  float64
#  2   Informational            98000 non-null  int64
#  3   Informational_Duration   98000 non-null  float64
#  4   ProductRelated           98000 non-null  int64
#  5   ProductRelated_Duration  98000 non-null  float64
#  6   BounceRates              98000 non-null  float64
#  7   ExitRates                98000 non-null  float64
#  8   PageValues               98000 non-null  float64
#  9   SpecialDay               98000 non-null  float64
#  10  Month                    98000 non-null  int64
#  11  OperatingSystems         98000 non-null  int64
#  12  Browser                  98000 non-null  int64
#  13  Region                   98000 non-null  int64
#  14  TrafficType              98000 non-null  int64
#  15  VisitorType              98000 non-null  int64
#  16  Weekend                  98000 non-null  int64
# dtypes: float64(7), int64(10)
# memory usage: 12.7 MB

# %%
df.isnull().sum()
# Out:
# Administrative             0
# Administrative_Duration    0
# Informational              0
# Informational_Duration     0
# ProductRelated             0
# ProductRelated_Duration    0
# BounceRates                0
# ExitRates                  0
# PageValues                 0
# SpecialDay                 0
# Month                      0
# OperatingSystems           0
# Browser                    0
# Region                     0
# TrafficType                0
# VisitorType                0
# Weekend                    0
# dtype: int64

# %%
df.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_798a3_row0_col0, #T_798a3_row0_col1, #T_798a3_row0_col11, #T_798a3_row0_col13, #T_798a3_row1_col4, #T_798a3_row1_col6, #T_798a3_row1_col7, #T_798a3_row1_col10, #T_798a3_row1_col14, #T_798a3_row1_col15, #T_798a3_row1_col16, #T_798a3_row2_col5, #T_798a3_row2_col12, #T_798a3_row2_col15, #T_798a3_row3_col2, #T_798a3_row3_col3, #T_798a3_row3_col8, #T_798a3_row3_col9, #T_798a3_row3_col14, #T_798a3_row3_col15, #T_798a3_row4_col16 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_798a3_row0_col2, #T_798a3_row0_col14, #T_798a3_row0_col15, #T_798a3_row0_col16, #T_798a3_row1_col9, #T_798a3_row1_col11, #T_798a3_row2_col1, #T_798a3_row2_col3, #T_798a3_row2_col6, #T_798a3_row2_col13, #T_798a3_row2_col16, #T_798a3_row3_col0, #T_798a3_row3_col10, #T_798a3_row3_col12, #T_798a3_row3_col16, #T_798a3_row4_col0, #T_798a3_row4_col4, #T_798a3_row4_col5, #T_798a3_row4_col7, #T_798a3_row4_col8, #T_798a3_row4_col12, #T_798a3_row4_col15 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_798a3_row0_col3 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_798a3_row0_col4 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_798a3_row0_col5 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_798a3_row0_col6 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_798a3_row0_col7, #T_798a3_row1_col0 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_798a3_row0_col8 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_798a3_row0_col9 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_798a3_row0_col10, #T_798a3_row2_col10, #T_798a3_row3_col6 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_798a3_row0_col12 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_798a3_row1_col1 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_798a3_row1_col2 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_798a3_row1_col3, #T_798a3_row4_col13 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_798a3_row1_col5 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_798a3_row1_col8 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_798a3_row1_col12 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_798a3_row1_col13, #T_798a3_row2_col8 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_798a3_row2_col0 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_798a3_row2_col2 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_798a3_row2_col4 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_798a3_row2_col7 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_798a3_row2_col9 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_798a3_row2_col11 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_798a3_row2_col14 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_798a3_row3_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_798a3_row3_col4 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_798a3_row3_col5 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_798a3_row3_col7 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_798a3_row3_col11, #T_798a3_row4_col11 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_798a3_row3_col13 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_798a3_row4_col1 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_798a3_row4_col2 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_798a3_row4_col3 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_798a3_row4_col6 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_798a3_row4_col9 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_798a3_row4_col10 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_798a3_row4_col14 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# </style>
# <table id="T_798a3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_798a3_level0_col0" class="col_heading level0 col0" >Administrative</th>
#       <th id="T_798a3_level0_col1" class="col_heading level0 col1" >Administrative_Duration</th>
#       <th id="T_798a3_level0_col2" class="col_heading level0 col2" >Informational</th>
#       <th id="T_798a3_level0_col3" class="col_heading level0 col3" >Informational_Duration</th>
#       <th id="T_798a3_level0_col4" class="col_heading level0 col4" >ProductRelated</th>
#       <th id="T_798a3_level0_col5" class="col_heading level0 col5" >ProductRelated_Duration</th>
#       <th id="T_798a3_level0_col6" class="col_heading level0 col6" >BounceRates</th>
#       <th id="T_798a3_level0_col7" class="col_heading level0 col7" >ExitRates</th>
#       <th id="T_798a3_level0_col8" class="col_heading level0 col8" >PageValues</th>
#       <th id="T_798a3_level0_col9" class="col_heading level0 col9" >SpecialDay</th>
#       <th id="T_798a3_level0_col10" class="col_heading level0 col10" >Month</th>
#       <th id="T_798a3_level0_col11" class="col_heading level0 col11" >OperatingSystems</th>
#       <th id="T_798a3_level0_col12" class="col_heading level0 col12" >Browser</th>
#       <th id="T_798a3_level0_col13" class="col_heading level0 col13" >Region</th>
#       <th id="T_798a3_level0_col14" class="col_heading level0 col14" >TrafficType</th>
#       <th id="T_798a3_level0_col15" class="col_heading level0 col15" >VisitorType</th>
#       <th id="T_798a3_level0_col16" class="col_heading level0 col16" >Weekend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_798a3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_798a3_row0_col0" class="data row0 col0" >26</td>
#       <td id="T_798a3_row0_col1" class="data row0 col1" >1861.127910</td>
#       <td id="T_798a3_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_798a3_row0_col3" class="data row0 col3" >886.547213</td>
#       <td id="T_798a3_row0_col4" class="data row0 col4" >612</td>
#       <td id="T_798a3_row0_col5" class="data row0 col5" >34351.072907</td>
#       <td id="T_798a3_row0_col6" class="data row0 col6" >0.052226</td>
#       <td id="T_798a3_row0_col7" class="data row0 col7" >0.145315</td>
#       <td id="T_798a3_row0_col8" class="data row0 col8" >265.704265</td>
#       <td id="T_798a3_row0_col9" class="data row0 col9" >0.613161</td>
#       <td id="T_798a3_row0_col10" class="data row0 col10" >9</td>
#       <td id="T_798a3_row0_col11" class="data row0 col11" >6</td>
#       <td id="T_798a3_row0_col12" class="data row0 col12" >9</td>
#       <td id="T_798a3_row0_col13" class="data row0 col13" >8</td>
#       <td id="T_798a3_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_798a3_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_798a3_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_798a3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_798a3_row1_col0" class="data row1 col0" >25</td>
#       <td id="T_798a3_row1_col1" class="data row1 col1" >1022.876853</td>
#       <td id="T_798a3_row1_col2" class="data row1 col2" >19</td>
#       <td id="T_798a3_row1_col3" class="data row1 col3" >426.138361</td>
#       <td id="T_798a3_row1_col4" class="data row1 col4" >662</td>
#       <td id="T_798a3_row1_col5" class="data row1 col5" >54291.755536</td>
#       <td id="T_798a3_row1_col6" class="data row1 col6" >0.147394</td>
#       <td id="T_798a3_row1_col7" class="data row1 col7" >0.159848</td>
#       <td id="T_798a3_row1_col8" class="data row1 col8" >53.901211</td>
#       <td id="T_798a3_row1_col9" class="data row1 col9" >0.018597</td>
#       <td id="T_798a3_row1_col10" class="data row1 col10" >11</td>
#       <td id="T_798a3_row1_col11" class="data row1 col11" >2</td>
#       <td id="T_798a3_row1_col12" class="data row1 col12" >11</td>
#       <td id="T_798a3_row1_col13" class="data row1 col13" >5</td>
#       <td id="T_798a3_row1_col14" class="data row1 col14" >19</td>
#       <td id="T_798a3_row1_col15" class="data row1 col15" >2</td>
#       <td id="T_798a3_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#     <tr>
#       <th id="T_798a3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_798a3_row2_col0" class="data row2 col0" >20</td>
#       <td id="T_798a3_row2_col1" class="data

# %%
df.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_c1e9c_row0_col0, #T_c1e9c_row0_col1, #T_c1e9c_row0_col11, #T_c1e9c_row0_col13, #T_c1e9c_row1_col4, #T_c1e9c_row1_col6, #T_c1e9c_row1_col7, #T_c1e9c_row1_col10, #T_c1e9c_row1_col14, #T_c1e9c_row1_col15, #T_c1e9c_row1_col16, #T_c1e9c_row2_col5, #T_c1e9c_row2_col12, #T_c1e9c_row2_col15, #T_c1e9c_row3_col2, #T_c1e9c_row3_col3, #T_c1e9c_row3_col8, #T_c1e9c_row3_col9, #T_c1e9c_row3_col14, #T_c1e9c_row3_col15, #T_c1e9c_row4_col16 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c1e9c_row0_col2, #T_c1e9c_row0_col14, #T_c1e9c_row0_col15, #T_c1e9c_row0_col16, #T_c1e9c_row1_col9, #T_c1e9c_row1_col11, #T_c1e9c_row2_col1, #T_c1e9c_row2_col3, #T_c1e9c_row2_col6, #T_c1e9c_row2_col13, #T_c1e9c_row2_col16, #T_c1e9c_row3_col0, #T_c1e9c_row3_col10, #T_c1e9c_row3_col12, #T_c1e9c_row3_col16, #T_c1e9c_row4_col0, #T_c1e9c_row4_col4, #T_c1e9c_row4_col5, #T_c1e9c_row4_col7, #T_c1e9c_row4_col8, #T_c1e9c_row4_col12, #T_c1e9c_row4_col15 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c1e9c_row0_col3 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_c1e9c_row0_col4 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_c1e9c_row0_col5 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_c1e9c_row0_col6 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_c1e9c_row0_col7, #T_c1e9c_row1_col0 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_c1e9c_row0_col8 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_c1e9c_row0_col9 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_c1e9c_row0_col10, #T_c1e9c_row2_col10, #T_c1e9c_row3_col6 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_c1e9c_row0_col12 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_c1e9c_row1_col1 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_c1e9c_row1_col2 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_c1e9c_row1_col3, #T_c1e9c_row4_col13 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_c1e9c_row1_col5 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_c1e9c_row1_col8 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_c1e9c_row1_col12 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_c1e9c_row1_col13, #T_c1e9c_row2_col8 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_c1e9c_row2_col0 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_c1e9c_row2_col2 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_c1e9c_row2_col4 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_c1e9c_row2_col7 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_c1e9c_row2_col9 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_c1e9c_row2_col11 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_c1e9c_row2_col14 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_c1e9c_row3_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_c1e9c_row3_col4 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_c1e9c_row3_col5 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_c1e9c_row3_col7 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_c1e9c_row3_col11, #T_c1e9c_row4_col11 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_c1e9c_row3_col13 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_c1e9c_row4_col1 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_c1e9c_row4_col2 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_c1e9c_row4_col3 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_c1e9c_row4_col6 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_c1e9c_row4_col9 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_c1e9c_row4_col10 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_c1e9c_row4_col14 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# </style>
# <table id="T_c1e9c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1e9c_level0_col0" class="col_heading level0 col0" >Administrative</th>
#       <th id="T_c1e9c_level0_col1" class="col_heading level0 col1" >Administrative_Duration</th>
#       <th id="T_c1e9c_level0_col2" class="col_heading level0 col2" >Informational</th>
#       <th id="T_c1e9c_level0_col3" class="col_heading level0 col3" >Informational_Duration</th>
#       <th id="T_c1e9c_level0_col4" class="col_heading level0 col4" >ProductRelated</th>
#       <th id="T_c1e9c_level0_col5" class="col_heading level0 col5" >ProductRelated_Duration</th>
#       <th id="T_c1e9c_level0_col6" class="col_heading level0 col6" >BounceRates</th>
#       <th id="T_c1e9c_level0_col7" class="col_heading level0 col7" >ExitRates</th>
#       <th id="T_c1e9c_level0_col8" class="col_heading level0 col8" >PageValues</th>
#       <th id="T_c1e9c_level0_col9" class="col_heading level0 col9" >SpecialDay</th>
#       <th id="T_c1e9c_level0_col10" class="col_heading level0 col10" >Month</th>
#       <th id="T_c1e9c_level0_col11" class="col_heading level0 col11" >OperatingSystems</th>
#       <th id="T_c1e9c_level0_col12" class="col_heading level0 col12" >Browser</th>
#       <th id="T_c1e9c_level0_col13" class="col_heading level0 col13" >Region</th>
#       <th id="T_c1e9c_level0_col14" class="col_heading level0 col14" >TrafficType</th>
#       <th id="T_c1e9c_level0_col15" class="col_heading level0 col15" >VisitorType</th>
#       <th id="T_c1e9c_level0_col16" class="col_heading level0 col16" >Weekend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1e9c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1e9c_row0_col0" class="data row0 col0" >26</td>
#       <td id="T_c1e9c_row0_col1" class="data row0 col1" >1861.127910</td>
#       <td id="T_c1e9c_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_c1e9c_row0_col3" class="data row0 col3" >886.547213</td>
#       <td id="T_c1e9c_row0_col4" class="data row0 col4" >612</td>
#       <td id="T_c1e9c_row0_col5" class="data row0 col5" >34351.072907</td>
#       <td id="T_c1e9c_row0_col6" class="data row0 col6" >0.052226</td>
#       <td id="T_c1e9c_row0_col7" class="data row0 col7" >0.145315</td>
#       <td id="T_c1e9c_row0_col8" class="data row0 col8" >265.704265</td>
#       <td id="T_c1e9c_row0_col9" class="data row0 col9" >0.613161</td>
#       <td id="T_c1e9c_row0_col10" class="data row0 col10" >9</td>
#       <td id="T_c1e9c_row0_col11" class="data row0 col11" >6</td>
#       <td id="T_c1e9c_row0_col12" class="data row0 col12" >9</td>
#       <td id="T_c1e9c_row0_col13" class="data row0 col13" >8</td>
#       <td id="T_c1e9c_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_c1e9c_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_c1e9c_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c1e9c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c1e9c_row1_col0" class="data row1 col0" >25</td>
#       <td id="T_c1e9c_row1_col1" class="data row1 col1" >1022.876853</td>
#       <td id="T_c1e9c_row1_col2" class="data row1 col2" >19</td>
#       <td id="T_c1e9c_row1_col3" class="data row1 col3" >426.138361</td>
#       <td id="T_c1e9c_row1_col4" class="data row1 col4" >662</td>
#       <td id="T_c1e9c_row1_col5" class="data row1 col5" >54291.755536</td>
#       <td id="T_c1e9c_row1_col6" class="data row1 col6" >0.147394</td>
#       <td id="T_c1e9c_row1_col7" class="data row1 col7" >0.159848</td>
#       <td id="T_c1e9c_row1_col8" class="data row1 col8" >53.901211</td>
#       <td id="T_c1e9c_row1_col9" class="data row1 col9" >0.018597</td>
#       <td id="T_c1e9c_row1_col10" class="data row1 col10" >11</td>
#       <td id="T_c1e9c_row1_col11" class="data row1 col11" >2</td>
#       <td id="T_c1e9c_row1_col12" class="data row1 col12" >11</td>
#       <td id="T_c1e9c_row1_col13" class="data row1 col13" >5</td>
#       <td id="T_c1e9c_row1_col14" class="data row1 col14" >19</td>
#       <td id="T_c1e9c_row1_col15" class="data row1 col15" >2</td>
#       <td id="T_c1e9c_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c1e9c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c1e9c_row2_col0" class="data row2 col0" >20</td>
#       <td id="T_c1e9c_row2_col1" class="data

# %%
df.describe()
# Out:
#        Administrative  Administrative_Duration  Informational  \
# count    98000.000000             98000.000000   98000.000000
# mean        13.470429              1706.117887      11.965092
# std          8.069361               980.180099       7.196502
# min          0.000000                 0.019749       0.000000
# 25%          6.000000               856.812806       6.000000
# 50%         13.000000              1710.024474      12.000000
# 75%         20.000000              2555.643540      18.000000
# max         27.000000              3398.706448      24.000000
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# count            98000.000000    98000.000000             98000.000000
# mean              1271.142517      352.837827             31985.100863
# std                735.649668      204.026481             18449.585420
# min                  0.028320        0.000000                 0.833681
# 25%                633.801242      177.000000             15985.650481
# 50%               1265.264967      353.000000             32045.630448
# 75%               1910.210830      530.000000             47910.978300
# max               2549.347690      705.000000             63972.958473
#
#         BounceRates     ExitRates    PageValues    SpecialDay         Month  \
# count  98000.000000  98000.000000  98000.000000  98000.000000  98000.000000
# mean       0.099918      0.099886    181.294884      0.499371      5.494745
# std        0.057650      0.057724    104.557959      0.288945      3.452295
# min        0.000001      0.000001      0.002676      0.000005      0.000000
# 25%        0.050180      0.049938     90.309731      0.247946      2.000000
# 50%        0.099875      0.099922    181.311823      0.500222      6.000000
# 75%        0.149841      0.149710    271.885254      0.749894      8.000000
# max        0.200000      0.199999    361.755872      0.999966     11.000000
#
#        OperatingSystems       Browser        Region   TrafficType  \
# count      98000.000000  98000.000000  98000.000000  98000.000000
# mean           4.508939      6.986122      4.994265     10.507724
# std            2.291745      3.740453      2.578596      5.771585
# min            1.000000      1.000000      1.000000      1.000000
# 25%            3.000000      4.000000      3.000000      6.000000
# 50%            5.000000      7.000000      5.000000     11.000000
# 75%            7.000000     10.000000      7.000000     16.000000
# max            8.000000     13.000000      9.000000     20.000000
#
#         VisitorType       Weekend
# count  98000.000000  98000.000000
# mean       1.002510      0.500490
# std        0.816913      0.500002
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      1.000000
# max        2.000000      1.000000

# %%
df.columns
# Out:
# Index(['Administrative', 'Administrative_Duration', 'Informational',
#        'Informational_Duration', 'ProductRelated', 'ProductRelated_Duration',
#        'BounceRates', 'ExitRates', 'PageValues', 'SpecialDay', 'Month',
#        'OperatingSystems', 'Browser', 'Region', 'TrafficType', 'VisitorType',
#        'Weekend'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Administrative               int64
# Administrative_Duration    float64
# Informational                int64
# Informational_Duration     float64
# ProductRelated               int64
# ProductRelated_Duration    float64
# BounceRates                float64
# ExitRates                  float64
# PageValues                 float64
# SpecialDay                 float64
# Month                        int64
# OperatingSystems             int64
# Browser                      int64
# Region                       int64
# TrafficType                  int64
# VisitorType                  int64
# Weekend                      int64
# dtype: object

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 97995    False
# 97996    False
# 97997    False
# 97998    False
# 97999    False
# Length: 98000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr()
# Out:
#                          Administrative  Administrative_Duration  \
# Administrative                 1.000000                 0.014845
# Administrative_Duration        0.014845                 1.000000
# Informational                 -0.002757                 0.012047
# Informational_Duration        -0.013159                -0.010291
# ProductRelated                 0.015768                -0.008963
# ProductRelated_Duration        0.000241                -0.012300
# BounceRates                    0.000654                 0.003143
# ExitRates                     -0.001443                -0.006476
# PageValues                     0.007664                -0.014074
# SpecialDay                    -0.009312                 0.011181
# Month                          0.008348                 0.008138
# OperatingSystems              -0.028117                -0.017740
# Browser                       -0.006111                 0.001128
# Region                         0.006948                 0.001530
# TrafficType                   -0.006001                 0.006505
# VisitorType                    0.015192                -0.000990
# Weekend                        0.004560                 0.026279
#
#                          Informational  Informational_Duration  \
# Administrative               -0.002757               -0.013159
# Administrative_Duration       0.012047               -0.010291
# Informational                 1.000000                0.003910
# Informational_Duration        0.003910                1.000000
# ProductRelated               -0.022898                0.000211
# ProductRelated_Duration       0.043704               -0.013523
# BounceRates                   0.000686               -0.027389
# ExitRates                     0.007253               -0.003831
# PageValues                   -0.012919               -0.027292
# SpecialDay                    0.014478               -0.015667
# Month                         0.002667                0.015228
# OperatingSystems              0.009847                0.007550
# Browser                       0.001509                0.005428
# Region                       -0.008273                0.004504
# TrafficType                  -0.012679               -0.018238
# VisitorType                   0.013845               -0.007825
# Weekend                      -0.003645                0.008248
#
#                          ProductRelated  ProductRelated_Duration  BounceRates  \
# Administrative                 0.015768                 0.000241     0.000654
# Administrative_Duration       -0.008963                -0.012300     0.003143
# Informational                 -0.022898                 0.043704     0.000686
# Informational_Duration         0.000211                -0.013523    -0.027389
# ProductRelated                 1.000000                 0.001840     0.015704
# ProductRelated_Duration        0.001840                 1.000000     0.016717
# BounceRates                    0.015704                 0.016717     1.000000
# ExitRates                      0.014379                -0.006115     0.002738
# PageValues                     0.012465                -0.004118    -0.006489
# SpecialDay                    -0.007820                 0.022411     0.013607
# Month                         -0.003506                 0.000849     0.003324
# OperatingSystems              -0.000686                 0.024631    -0.005980
# Browser                       -0.014460                 0.020132    -0.011608
# Region                         0.003910                 0.000535     0.027498
# TrafficType                    0.004298                -0.001038     0.016982
# VisitorType                    0.033791                -0.010919    -0.000829
# Weekend                        0.016857                 0.004792    -0.008998
#
#                          ExitRates  PageValues  SpecialDay     Month  \
# Administrative           -0.001443    0.007664   -0.009312  0.008348
# Administrative_Duration  -0.006476   -0.014074    0.011181  0.008138
# Informational             0.007253   -0.012919    0.014478  0.002667
# Informational_Duration   -0.003831   -0.027292   -0.015667  0.015228
# ProductRelated            0.014379    0.012465   -0.007820 -0.003506
# ProductRelated_Duration  -0.006115   -0.004118    0.022411  0.000849
# BounceRates               0.002738   -0.006489    0.013607  0.003324
# ExitRates                 1.000000    0.001563   -0.015309  0.003744
# PageValues                0.001563    1.000000    0.006005 -0.004840
# SpecialDay               -0.015309    0.006005    1.000000 -0.008935
# Month                     0.003744   -0.004840   -0.008935  1.000000
# OperatingSystems         -0.010971   -0.024719   -0.007352 -0.000255
# Browser                  -0.022050   -0.001833   -0.006028  0.000521
# Region                   -0.010042    0.010977    0.008749 -0.013007
# TrafficType               0.008266    0.016695    0.009573  0.000162
# VisitorType               0.005728   -0.006424    0.015289  0.002435
# Weekend                  -0.004311   -0.002722   -0.011298 -0.006290
#
#                          OperatingSystems   Browser    Region  TrafficType  \
# Administrative                  -0.028117 -0.006111  0.006948    -0.006001
# Administrative_Duration         -0.017740  0.001128  0.001530     0.006505
# Informational                    0.009847  0.001509 -0.008273    -0.012679
# Informational_Duration           0.007550  0.005428  0.004504    -0.018238
# ProductRelated                  -0.000686 -0.014460  0.003910     0.004298
# ProductRelated_Duration          0.024631  0.020132  0.000535    -0.001038
# BounceRates                     -0.005980 -0.011608  0.027498     0.016982
# ExitRates                       -0.010971 -0.022050 -0.010042     0.008266
# PageValues                      -0.024719 -0.001833  0.010977     0.016695
# SpecialDay                      -0.007352 -0.006028  0.008749     0.009573
# Month                           -0.000255  0.000521 -0.013007     0.000162
# OperatingSystems                 1.000000 -0.016607  0.002776     0.002041
# Browser                         -0.016607  1.000000 -0.006283    -0.003356
# Region                           0.002776 -0.006283  1.000000     0.009701
# TrafficType                      0.002041 -0.003356  0.009701     1.000000
# VisitorType                     -0.009703  0.006183 -0.024590    -0.011445
# Weekend                          0.006391 -0.008073 -0.009931     0.013087
#
#                          VisitorType   Weekend
# Administrative              0.015192  0.004560
# Administrative_Duration    -0.000990  0.026279
# Informational               0.013845 -0.003645
# Informational_Duration     -0.007825  0.008248
# ProductRelated              0.033791  0.016857
# ProductRelated_Duration    -0.010919  0.004792
# BounceRates                -0.000829 -0.008998
# ExitRates                   0.005728 -0.004311
# PageValues                 -0.006424 -0.002722
# SpecialDay                  0.015289 -0.011298
# Month                       0.002435 -0.006290
# OperatingSystems           -0.009703  0.006391
# Browser                     0.006183 -0.008073
# Region                     -0.024590 -0.009931
# TrafficType                -0.011445  0.013087
# VisitorType                 1.000000  0.005323
# Weekend                     0.005323  1.000000

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.heatmap(np.abs(df.corr()),cmap='Purples')
plt.show()

# %%
sns.heatmap(np.abs(df.corr())>1,cmap='Greens')
plt.show()
